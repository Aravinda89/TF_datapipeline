# %%
import tensorflow
tensorflow.__version__
# Out:
# '2.0.0'

# %%
from tensorflow.keras import datasets
from numpy.random import randint
from helpers import display_imgs, class_count

import matplotlib.pyplot as plt

# %%
(train_imgs, train_labels), (val_imgs, val_labels) = datasets.cifar10.load_data()

# %%
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer',
               'dog', 'frog', 'horse', 'ship', 'truck']

# %%
display_imgs(train_imgs, train_labels, class_names)

# %%
train_labels_list = [i[0] for i in train_labels]
test_labels_list = [i[0] for i in val_labels]

# %%
class_count(class_names, train_labels_list,'TRAIN')
class_count(class_names, test_labels_list,'TEST')
# Out:
#     <!DOCTYPE html>
#     <html>
#       <head>
#       <script type="text/javascript" src="http://kozea.github.com/pygal.js/javascripts/svg.jquery.js"></script>
#       <script type="text/javascript" src="https://kozea.github.io/pygal.js/2.0.x/pygal-tooltips.min.js""></script>
#       </head>
#       <body>
#         <figure>
#           <?xml version='1.0' encoding='utf-8'?>
# ...
