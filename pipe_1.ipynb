# %%
import tensorflow
tensorflow.__version__
# Out:
# '2.0.0'

# %%
from tensorflow.keras import datasets
from numpy.random import randint
from helpers import display_imgs, class_count

import matplotlib.pyplot as plt

# %%
(train_imgs, train_labels), (val_imgs, val_labels) = datasets.cifar10.load_data()

# %%
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer',
               'dog', 'frog', 'horse', 'ship', 'truck']

# %%
display_imgs(train_imgs, train_labels, class_names)

# %%
labels_list = [i[0] for i in train_labels]

# %%
class_count(class_names, labels_list,'TRAIN')
# Out:
#     <!DOCTYPE html>
#     <html>
#       <head>
#       <script type="text/javascript" src="http://kozea.github.com/pygal.js/javascripts/svg.jquery.js"></script>
#       <script type="text/javascript" src="https://kozea.github.io/pygal.js/2.0.x/pygal-tooltips.min.js""></script>
#       </head>
#       <body>
#         <figure>
#           <?xml version='1.0' encoding='utf-8'?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="chart-93dcb472-0c03-46dc-a47d-c3c5054be7c6" class="pygal-chart" viewBox="0 0 800 300"><!--Generated with pygal 2.4.0 (lxml) ©Kozea 2012-2016 on 2020-01-05--><!--http://pygal.org--><!--http://github.com/Kozea/pygal--><defs><style type="text/css">#chart-93dcb472-0c03-46dc-a47d-c3c5054be7c6{-webkit-user-select:none;-webkit-font-smoothing:antialiased;font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace}#chart-93dcb472-0c03-46dc-a47d-c3c5054be7c6 .title{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-93dcb472-0c03-46dc-a47d-c3c5054be7c6 .legends .legend text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-93dcb472-0c03-46dc-a47d-c3c5054be7c6 .axis text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-93dcb472-0c03-46dc-a47d-c3c5054be7c6 .axis text.major{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-93dcb472-0c03-46dc-a47d-c3c5054be7c6 .text-overlay text.value{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-93dcb472-0c03-46dc-a47d-c3c5054be7c6 .text-overlay text.label{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-93dcb472-0c03-46dc-a47d-c3c5054be7c6 .tooltip{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-93dcb472-0c03-46dc-a47d-c3c5054be7c6 text.no_data{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:64px}
# #chart-93dcb472-0c03-46dc-a47d-c3c5054be7c6{background-color:rgba(249,249,249,1)}#chart-93dcb472-0c03-46dc-a47d-c3c5054be7c6 path,#chart-93dcb472-0c03-46dc-a47d-c3c5054be7c6 line,#chart-93dcb472-0c03-46dc-a47d-c3c5054be7c6 rect,#chart-93dcb472-0c03-46dc-a47d-c3c5054be7c6 circle{-webkit-transition:150ms;-moz-transition:150ms;transition:150ms}#chart-93dcb472-0c03-46dc-a47d-c3c5054be7c6 .graph &gt; .background{fill:rgba(249,249,249,1)}#chart-93dcb472-0c03-46dc-a47d-c3c5054be7c6 .plot &gt; .background{fill:rgba(255,255,255,1)}#chart-93dcb472-0c03-46dc-a47d-c3c5054be7c6 .graph{fill:rgba(0,0,0,.87)}#chart-93dcb472-0c03-46dc-a47d-c3c5054be7c6 text.no_data{fill:rgba(0,0,0,1)}#chart-93dcb472-0c03-46dc-a47d-c3c5054be7c6 .title{fill:rgba(0,0,0,1)}#chart-93dcb472-0c03-46dc-a47d-c3c5054be7c6 .legends .legend text{fill:rgba(0,0,0,.87)}#chart-93dcb472-0c03-46dc-a47d-c3c5054be7c6 .legends .legend:hover text{fill:rgba(0,0,0,1)}#chart-93dcb472-0c03-46dc-a47d-c3c5054be7c6 .axis .line{stroke:rgba(0,0,0,1)}#chart-93dcb472-0c03-46dc-a47d-c3c5054be7c6 .axis .guide.line{stroke:rgba(0,0,0,.54)}#chart-93dcb472-0c03-46dc-a47d-c3c5054be7c6 .axis .major.line{stroke:rgba(0,0,0,.87)}#chart-93dcb472-0c03-46dc-a47d-c3c5054be7c6 .axis text.major{fill:rgba(0,0,0,1)}#chart-93dcb472-0c03-46dc-a47d-c3c5054be7c6 .axis.y .guides:hover .guide.line,#chart-93dcb472-0c03-46dc-a47d-c3c5054be7c6 .line-graph .axis.x .guides:hover .guide.line,#chart-93dcb472-0c03-46dc-a47d-c3c5054be7c6 .stackedline-graph .axis.x .guides:hover .guide.line,#chart-93dcb472-0c03-46dc-a47d-c3c5054be7c6 .xy-graph .axis.x .guides:hover .guide.line{stroke:rgba(0,0,0,1)}#chart-93dcb472-0c03-46dc-a47d-c3c5054be7c6 .axis .guides:hover text{fill:rgba(0,0,0,1)}#chart-93dcb472-0c03-46dc-a47d-c3c5054be7c6 .reactive{fill-opacity:.7;stroke-opacity:.8}#chart-93dcb472-0c03-46dc-a47d-c3c5054be7c6 .ci{stroke:rgba(0,0,0,.87)}#chart-93dcb472-0c03-46dc-a47d-c3c5054be7c6 .reactive.active,#chart-93dcb472-0c03-46dc-a47d-c3c5054be7c6 .active .reactive{fill-opacity:.8;stroke-opacity:.9;stroke-width:4}#chart-93dcb472-0c03-46dc-a47d-c3c5054be7c6 .ci .reactive.active{stroke-width:1.5}#chart-93dcb472-0c03-46dc-a47d-c3c5054be7c6 .series text{fill:rgba(0,0,0,1)}#chart-93dcb472-0c03-46dc-a47d-c3c5054be7c6 .tooltip rect{fill:rgba(255,255,255,1);stroke:rgba(0,0,0,1);-webkit-transition:opacity 150ms;-moz-transition:opacity 150ms;transition:opacity 150ms}#chart-93dcb472-0c03-46dc-a47d-c3c5054be7c6 .tooltip .label{fill:rgba(0,0,0,.87)}#chart-93dcb472-0c03-46dc-a47d-c3c5054be7c6 .tooltip .label{fill:rgba(0,0,0,.87)}#chart-93dcb472-0c03-46dc-a47d-c3c5054be7c6 .tooltip .legend{font-size:.8em;fill:rgba(0,0,0,.54)}#chart-93dcb472-0c03-46dc-a47d-c3c5054be7c6 .tooltip .x_label{font-size:.6em;fill:rgba(0,0,0,1)}#chart-93dcb472-0c03-46dc-a47d-c3c5054be7c6 .tooltip .xlink{font-size:.5em;text-decoration:underline}#chart-93dcb472-0c03-46dc-a47d-c3c5054be7c6 .tooltip .value{font-size:1.5em}#chart-93dcb472-0c03-46dc-a47d-c3c5054be7c6 .bound{font-size:.5em}#chart-93dcb472-0c03-46dc-a47d-c3c5054be7c6 .max-value{font-size:.75em;fill:rgba(0,0,0,.54)}#chart-93dcb472-0c03-46dc-a47d-c3c5054be7c6 .map-element{fill:rgba(255,255,255,1);stroke:rgba(0,0,0,.54) !important}#chart-93dcb472-0c03-46dc-a47d-c3c5054be7c6 .map-element .reactive{fill-opacity:inherit;stroke-opacity:inherit}#chart-93dcb472-0c03-46dc-a47d-c3c5054be7c6 .color-0,#chart-93dcb472-0c03-46dc-a47d-c3c5054be7c6 .color-0 a:visited{stroke:#F44336;fill:#F44336}#chart-93dcb472-0c03-46dc-a47d-c3c5054be7c6 .color-1,#chart-93dcb472-0c03-46dc-a47d-c3c5054be7c6 .color-1 a:visited{stroke:#3F51B5;fill:#3F51B5}#chart-93dcb472-0c03-46dc-a47d-c3c5054be7c6 .color-2,#chart-93dcb472-0c03-46dc-a47d-c3c5054be7c6 .color-2 a:visited{stroke:#009688;fill:#009688}#chart-93dcb472-0c03-46dc-a47d-c3c5054be7c6 .color-3,#chart-93dcb472-0c03-46dc-a47d-c3c5054be7c6 .color-3 a:visited{stroke:#FFC107;fill:#FFC107}#chart-93dcb472-0c03-46dc-a47d-c3c5054be7c6 .color-4,#chart-93dcb472-0c03-46dc-a47d-c3c5054be7c6 .color-4 a:visit ...
# #chart-93dcb472-0c03-46dc-a47d-c3c5054be7c6 text.no_data{text-anchor:middle}#chart-93dcb472-0c03-46dc-a47d-c3c5054be7c6 .guide.line{fill:none}#chart-93dcb472-0c03-46dc-a47d-c3c5054be7c6 .centered{text-anchor:middle}#chart-93dcb472-0c03-46dc-a47d-c3c5054be7c6 .title{text-anchor:middle}#chart-93dcb472-0c03-46dc-a47d-c3c5054be7c6 .legends .legend text{fill-opacity:1}#chart-93dcb472-0c03-46dc-a47d-c3c5054be7c6 .axis.x text{text-anchor:middle}#chart
